# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
y=np.array([5,20])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
y=np.array([5,20])

plt.plot(x,y,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
y=np.array([5,20])

plt.plot(x,y,marker='o',ms=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
y=np.array([5,20])

plt.plot(x,y,marker='o',ms=10,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
y=np.array([5,20])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4])
y=np.array([5,20])

plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array5,10,20,40])([
x=np.array(['Hindi','English','Punjabi','Bengali'])

plt.pie(y,labels=x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([5,10,20,40])
x=np.array(['Hindi','English','Punjabi','Bengali'])
ex=np.array([0,0.1,0,0.1])

plt.pie(y,labels=x,explode=ex)
plt.show()
