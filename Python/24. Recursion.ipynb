# %%
def calc(n):
    if n==1:
        return 1
    else:
        return n*calc(n-1)

print(calc(4))
# Out:
# 24

# %%
def calc(n):
    if n==1:
        return 1
    else:
        return n*calc(n-1)

n=int(input('Enter a number'))
x=calc(n)
print('Factorial',x)
# Out:
# Enter a number6
# Factorial 720
