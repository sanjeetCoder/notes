# %%
x=10
y=9
print(x&y)
# Out:
# 8

# %%
x=10
y=9
print(x|y)
# Out:
# 11

# %%
x=10
y=9
print(x^y)
# Out:
# 3

# %%
x=~10
print(x)
# Out:
# -11

# %%
x=10<<2
print(x)
# Out:
# 40

# %%
x=10>>2
print(x)
# Out:
# 2
