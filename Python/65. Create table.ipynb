# %%
import mysql.connector

db=mysql.connector.connect(
host="localhost",
user="root",
password="Sanjeet@123",
database="students"
)

cursor=db.cursor()
cursor.execute("create table customers(id int not null, name varchar(30))")
